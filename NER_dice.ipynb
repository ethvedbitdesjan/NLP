# %% [markdown]
# <a href="https://colab.research.google.com/github/ethvedbitdesjan/NLP/blob/main/NER_dice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive'
# Out:
# /content/gdrive/MyDrive

# %%
# !pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 735.4 MB 16 kB/s
# ...
#      |████████████████████████████████| 12.8 MB 3.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 4.6 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
#     Uninstalling torchaudio-0.12.1+cu113:
#       Successfully uninstalled torchaudio-0.12.1+cu113
# ...

# %%
# !pip install -r /content/gdrive/MyDrive/dice_loss/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 408 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 52.1 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 39.3 MB/s
# ...
#      |████████████████████████████████| 6.9 MB 55.2 MB/s
# ...
#      |████████████████████████████████| 829 kB 64.6 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 51.6 MB/s
# ...
#      |████████████████████████████████| 880 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 59.6 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=b474754213bbd97e04f78e05361ecf50aeee053e753e6b65e0ee0ba51d8cd12e
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=50dd8ddcbdffa52fb092c71a9757d444d7e1d4e95c1eab9a5db297dc5295a9d0
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python /content/gdrive/MyDrive/dice_loss/dice_trainer.py \
--gpus="1" \
--precision=16 \
--train_batch_size 36 \
--progress_bar_refresh_rate 1 \
--val_check_interval 0.25 \
--max_length 256 \
--optimizer torch.adam \
--data_dir /content/gdrive/MyDrive/dice_loss/ \
--bert_dropout 0.2 \
--bert_config_dir bert-base-cased \
--lr 3e-5 \
--lr_scheduler polydecay \
--accumulate_grad_batches 8 \
--default_root_dir /content/gdrive/MyDrive/dice_loss/ \
--output_dir /content/gdrive/MyDrive/dice_loss/ \
--max_epochs 3 \
--gradient_clip_val 1.0 \
--weight_decay 0.01 \
--weight_start 1 \
--weight_end 1 \
--weight_span 0.3 \
--dice_smooth 1 \
--dice_alpha 0.01 \
--warmup_proportion 0.01 \
--span_loss_candidates gold_pred_random \
--construct_entity_span start_and_end \
--flat_ner \
--pred_answerable "train_infer" \
--answerable_task_ratio 0.4 \
--activate_func relu
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 2:  36% 19291/53561 [08:42<15:28, 36.91it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19298/53561 [08:42<15:28, 36.92it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19305/53561 [08:42<15:27, 36.92it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19312/53561 [08:42<15:27, 36.93it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19319/53561 [08:43<15:27, 36.93it/s, loss=0.099, v_num=0]
# Validating:  43% 5540/13000 [01:33<02:06, 58.75it/s]
# Epoch 2:  36% 19326/53561 [08:43<15:26, 36.94it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19333/53561 [08:43<15:26, 36.94it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19340/53561 [08:43<15:26, 36.95it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19347/53561 [08:43<15:25, 36.95it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19354/53561 [08:43<15:25, 36.96it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19361/53561 [08:43<15:25, 36.96it/s, loss=0.099, v_num=0]
# Epoch 2:  36% 19368/53561 [08:43<15:24, 36.97it/s, loss=0.099, v_num=0]
# ...

# %%
# !pip install pyyaml==5.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 4.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 /content/gdrive/MyDrive/dice_loss/evaluate.py \
--gpus="1" \
--precision 32 \
--path_to_model_checkpoint /content/gdrive/MyDrive/dice_loss/epoch=2_v2.ckpt
# Out:
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# INFO:lightning:TPU available: False, using: 0 TPU cores
# CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/core/saving.py:335: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   tags = yaml.load(fp)
# ...
